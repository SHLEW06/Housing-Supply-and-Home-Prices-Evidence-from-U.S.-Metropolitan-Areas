# %% [markdown]
# # **[Project Title]**
#
# ### ECON 320 Lab — Final Project
# **Student name(s):** [Name(s)]
# **Lab Section:** [#]
#
# ---
# ## Abstract
# [~120–180 words] We study whether **[X]** affects **[Y]** using **[dataset, years]**. The unit of observation is **[unit]**. The baseline specification is \(y_i = \beta_0 + \beta_1 x_i + \gamma'\,\text{controls}_i + u_i\). We find that **[main result in plain English: magnitude + direction]**. Results are **[robust/not robust]** to **[brief check]**. We discuss potential concerns about **omitted variables** and **multicollinearity** and their likely directions. Our findings suggest **[one implication]**.

# %% [markdown]
# ---
# ## 0. Setup
# *(Keep this minimal. Add only the libraries you actually use.)*

# %% [markdown]
# ---
# ## 1. Introduction
# [in short paragraphs]
# - **Research question:** What is the effect of **[X]** on **[Y]**?
# - **Why it matters:** Brief context / **motivation (policy, business, or academic relevance)**.
# - **Preview of approach:** Data source, basic model idea, and key result in one sentence.

# %% [markdown]
# ---
# ## 2. Data and Summary Statistics
# **Data source & unit.** Describe the dataset (source/URL/years), unit of observation, sample restrictions, and final sample size.
#
# **Variables.** Define the outcome $y$, main regressor $x$, and key controls (units and brief meaning). Mention any possible measurement limitations.
#
# ### 2.1 Load and prepare data

# %% [markdown]
# ### 2.2 Descriptive statistics *(table + figure)*
# Provide a brief observation in words (1–2 sentences) after each output.

# %% [markdown]
# ---
# ## 3. Empirical Strategy
# We estimate the following baseline model:
#
# $$
# y_i = \beta_0 + \beta_1 x_i + \gamma'\,\text{controls}_i + u_i \quad .
# $$
#
# - **Interpretation of $\beta_1$:** Plain English description (units and meaning).
# - **Identification concerns:**
#   - *Omitted Variable Bias (OVB):* Which relevant drivers might be missing? Direction of potential bias.
#   - *Multicollinearity:* Which controls potentially overlap with each other or with $x$? Any steps taken (e.g., variable selection, VIF check).
# - **Estimation:** OLS with clearly defined variables.

# %% [markdown]
# ### 3.1 Estimation details
# Define variables, fit the baseline, and report the coefficient on **$x$** and **$R^2$**. Keep outputs compact and readable.

# %% [markdown]
# ### 3.2 Diagnostic awareness
# - *Multicollinearity:* If relevant, comment (e.g., high VIFs or overlapping controls).
# - *Short vs. long spec (OVB sanity check):* Briefly compare a model omitting a suspected driver vs. your preferred model; note direction of change in $\beta_1$.

# %% [markdown]
# ---
# ## 4. Results
# Present one **main table/figure** and interpret key coefficients in plain English. Emphasize magnitudes and units, not only statistical significance.
#
# **Reading the table:** Explain $\beta_1$ clearly in plain English. Mention $R^2$ and any other notable coefficients.
#
# *Keep this section concise and directly tied to the research question.*

# %% [markdown]
# ---
# ## 5. Robustness and Limitations
# **Robustness.** Try one simple check (choose one): add/drop one control; transform a variable (e.g., logs); or split the sample. Report how $\beta_1$ changes (if at all).
#
# **Limitations.** Briefly discuss one or two realistic caveats (data coverage, measurement error, remaining endogeneity).

# %%
# TODO: Implement one robustness/sensitivity check (and summarize the takeaway in Markdown).
pass

# %% [markdown]
# ---
# ## 6. Conclusion
# [~1 short paragraph] Recap the answer to your research question, the main quantitative takeaway (with units), and one practical/policy implication. Keep it crisp and specific.

# %% [markdown]
# ---
# ## References (optional)
# - Data source(s): [name, link]
# - Any articles or documentation you directly relied on.
#
# ---
